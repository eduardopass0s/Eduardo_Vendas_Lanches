# %% [markdown]
# # 📘 Projeto de Programação Orientada a Objetos – 2º Bimestre
#
# **Nome do Aluno:**
#
# **Turma:**
#
# **Tema Escolhido:**

# %% [markdown]
# Lembre-se esse projeto deve ser personalizado, todas as classe e metodos devem ter uma referencia ao seu nome, exemplo:
#
# class Carro_Fabio:
#
#     def __init__(self, tipo, cor, rodas):
#         self.tipo = tipo
#         self.cor = cor
#         self.rodas = rodas
#
#     def alterar_cor_Fabio(self, nova_cor):
#         self.cor = nova_cor
#         return self.cor

# %%
# Desenvolva aqui o código da Parte 1
class Lanche:
    def __init__(self, nome, ingredientes, preco, tipo_molho=None):
        # Atributos da classe
        self.nome = nome
        self.ingredientes = ingredientes
        self.preco = preco
        self.tipo_molho = tipo_molho

    def exibir_dados(self):
  
        ingredientes_str = ", ".join(self.ingredientes)
        print(f"Lanche: {self.nome} | Ingredientes: {ingredientes_str} | Preço: R${self.preco:.2f}", end="")
        if self.tipo_molho:
            print(f" | Molho: {self.tipo_molho}")
        else:
            print()

lanche1 = Lanche("X-Burger", ["Pão", "Carne", "Queijo"], 12.50)
lanche2 = Lanche("X-Salada", ["Pão", "Carne", "Queijo", "Alface"], 14.00, "Maionese")

print("Dados dos lanches:")
lanche1.exibir_dados() 
lanche2.exibir_dados()
# Out:
# Dados dos lanches:
# Lanche: X-Burger | Ingredientes: Pão, Carne, Queijo | Preço: R$12.50
# Lanche: X-Salada | Ingredientes: Pão, Carne, Queijo, Alface | Preço: R$14.00 | Molho: Maionese

# %% [markdown]
# ## PARTE 2 – Métodos e Herança
#
# **Tarefas:**
# - Criar pelo menos 2 métodos de ação para a classe principal.
# - Criar uma subclasse herdando da classe principal.
# - Adicionar pelo menos 1 novo atributo e 1 novo método exclusivo na subclasse.
# - Utilizar `super()` no construtor da subclasse.
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 2
class Lanche:
    def __init__(self, nome, ingredientes, preco, tipo_molho=None):
        self.nome = nome
        self.ingredientes = ingredientes
        self.preco = preco
        self.tipo_molho = tipo_molho

    def exibir_dados(self):
        print(f"Lanche: {self.nome} | Ingredientes: {', '.join(self.ingredientes)} | Preço: R${self.preco:.2f}", end="")
        if self.tipo_molho:
            print(f" | Molho: {self.tipo_molho}")
        else:
            print()

    def aplicar_desconto(self, percentual):
        self.preco -= self.preco * (percentual / 100)
        print(f"Novo preço com {percentual}% de desconto: R${self.preco:.2f}")

    def verificar_categoria_preco(self):
        categoria = "caro" if self.preco >= 20 else "acessível"
        print(f"O lanche '{self.nome}' é {categoria}.")

class LancheVegano(Lanche):
    def __init__(self, nome, ingredientes, preco, tipo_molho=None, tipo_proteina="Vegetal"):
        super().__init__(nome, ingredientes, preco, tipo_molho)
        self.tipo_proteina = tipo_proteina

    def exibir_dados(self):
        super().exibir_dados()
        print(f"Tipo de proteína: {self.tipo_proteina}")

    def alterar_tipo_proteina(self, novo_tipo):
        self.tipo_proteina = novo_tipo
        print(f"Tipo de proteína alterado para: {self.tipo_proteina}")

lanche1 = Lanche("X-Burger", ["Pão", "Carne", "Queijo"], 12.50)
lanche2 = LancheVegano("X-Vegano", ["Pão", "Alface", "Tomate"], 18.00, "Molho Pesto", "Tofu")

lanche1.exibir_dados()
lanche2.exibir_dados()

lanche1.aplicar_desconto(10)
lanche2.aplicar_desconto(5)

lanche1.verificar_categoria_preco()
lanche2.verificar_categoria_preco()

lanche2.alterar_tipo_proteina("Seitan")
lanche2.exibir_dados()

# %% [markdown]
# ## PARTE 3 – Encapsulamento e Abstração
#
# **Tarefas:**
# - Tornar pelo menos 1 atributo da classe principal privado (`__atributo`).
# - Criar métodos `get` e `set` para o atributo privado.
# - Implementar um método que contenha lógica interna (ex: cálculo, verificação).
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 3
class Lanche:
    def __init__(self, nome, ingredientes, preco, tipo_molho=None):
        self.nome = nome
        self.ingredientes = ingredientes
        self.__preco = preco 
        self.tipo_molho = tipo_molho

    def get_preco(self):
        return self.__preco

    def set_preco(self, novo_preco):
        if novo_preco >= 0:
            self.__preco = novo_preco
            print(f"Preço atualizado para: R${self.__preco:.2f}")
        else:
            print("Erro: O preço não pode ser negativo.")

    def aplicar_desconto(self, percentual):
        desconto = self.__preco * (percentual / 100)
        self.__preco -= desconto
        print(f"Novo preço com {percentual}% de desconto: R${self.__preco:.2f}")

    def calcular_preco_final(self, percentual_imposto):
        preco_com_imposto = self.__preco * (1 + percentual_imposto / 100)
        return preco_com_imposto

    def exibir_dados(self):
        print(f"Lanche: {self.nome} | Ingredientes: {', '.join(self.ingredientes)} | Preço: R${self.__preco:.2f}", end="")
        if self.tipo_molho:
            print(f" | Molho: {self.tipo_molho}")
        else:
            print()

lanche1 = Lanche("X-Burger", ["Pão", "Carne", "Queijo"], 12.50)
lanche2 = Lanche("X-Salada", ["Pão", "Carne", "Queijo", "Alface"], 14.00, "Maionese")

lanche1.exibir_dados()
lanche2.exibir_dados()

lanche1.aplicar_desconto(10)
lanche2.aplicar_desconto(5)

preco_final_lanche1 = lanche1.calcular_preco_final(10)
preco_final_lanche2 = lanche2.calcular_preco_final(10)

print(f"Preço final do X-Burger com imposto: R${preco_final_lanche1:.2f}")
print(f"Preço final do X-Salada com imposto: R${preco_final_lanche2:.2f}")

lanche1.set_preco(15.00)  
lanche1.exibir_dados()

# %% [markdown]
# ## PARTE 4 – Polimorfismo e Banco de Dados
#
# **Tarefas:**
# - Implementar polimorfismo: sobrescrever um método na subclasse.
# - Integrar o sistema com banco de dados (MySQL ou SQLite).
# - Implementar inserção (INSERT), consulta (SELECT) e exclusão (DELETE) de registros no banco de dados.
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 4

class Lanche:
    def __init__(self, nome, ingredientes, preco, tipo_molho=None):
        self.nome = nome
        self.ingredientes = ingredientes
        self.__preco = preco  # Atributo privado
        self.tipo_molho = tipo_molho

    def get_preco(self):
        return self.__preco

    def set_preco(self, novo_preco):
        if novo_preco >= 0:
            self.__preco = novo_preco
            print(f"Preço atualizado para: R${self.__preco:.2f}")
        else:
            print("Erro: O preço não pode ser negativo.")

    def aplicar_desconto(self, percentual):
        self.__preco -= self.__preco * (percentual / 100)
        print(f"Novo preço com {percentual}% de desconto: R${self.__preco:.2f}")

    def calcular_preco_final(self, percentual_imposto):
        preco_com_imposto = self.__preco * (1 + percentual_imposto / 100)
        return preco_com_imposto

    def exibir_dados(self):
        print(f"Lanche: {self.nome} | Ingredientes: {', '.join(self.ingredientes)} | Preço: R${self.__preco:.2f}", end="")
        if self.tipo_molho:
            print(f" | Molho: {self.tipo_molho}")
        else:
            print()

# Subclasse (LancheVegano) que herda da classe Lanche
class LancheVegano(Lanche):
    def __init__(self, nome, ingredientes, preco, tipo_molho=None, tipo_proteina="Vegetal"):
        super().__init__(nome, ingredientes, preco, tipo_molho)
        self.tipo_proteina = tipo_proteina

    def exibir_dados(self):
        super().exibir_dados()  # Exibe os dados da classe pai
        print(f"Tipo de proteína: {self.tipo_proteina}")

# Banco de Dados Simulado em Memória
class BancoDeDados:
    def __init__(self):
        self.lanches_db = []  # Lista que simula o banco de dados

    def inserir_lanche(self, lanche):
        # Inserir um lanche na "tabela"
        self.lanches_db.append(lanche)
        print(f"Lanche '{lanche.nome}' inserido no banco de dados.")

    def listar_lanches(self):
        # Listar todos os lanches na "tabela"
        if not self.lanches_db:
            print("Nenhum lanche encontrado no banco de dados.")
            return
        print("\n--- Lanches no Banco de Dados ---")
        for lanche in self.lanches_db:
            lanche.exibir_dados()

    def excluir_lanche(self, nome):
        # Excluir um lanche pelo nome
        for lanche in self.lanches_db:
            if lanche.nome == nome:
                self.lanches_db.remove(lanche)
                print(f"Lanche '{nome}' removido do banco de dados.")
                return
        print(f"Lanche '{nome}' não encontrado no banco de dados.")

# Testando o código
def main():
    banco = BancoDeDados()

    # Criando objetos de lanches
    lanche1 = Lanche("X-Burger", ["Pão", "Carne", "Queijo"], 12.50)
    lanche2 = LancheVegano("X-Vegano", ["Pão", "Alface", "Tomate"], 18.00, "Molho Pesto", "Tofu")

    # Inserindo lanches no banco de dados
    banco.inserir_lanche(lanche1)
    banco.inserir_lanche(lanche2)

    # Listando lanches no banco
    banco.listar_lanches()

    # Excluindo um lanche do banco
    banco.excluir_lanche("X-Burger")  # Excluindo o lanche "X-Burger"

    # Listando lanches após a exclusão
    print("\n--- Lanches após exclusão ---")
    banco.listar_lanches()

if __name__ == "__main__":
    main()

# %% [markdown]
# ## PARTE 5 – Projeto Final e Organização
#
# **Tarefas:**
# - Consolidar todas as partes do projeto em um único script organizado.
# - Comentar o código explicando cada parte.
# - Testar todas as funcionalidades.
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 5
class Lanche:
    def __init__(self, nome, ingredientes, preco, tipo_molho=None):
        self.nome = nome
        self.ingredientes = ingredientes
        self.__preco = preco
        self.tipo_molho = tipo_molho

    def get_preco(self):
        return self.__preco

    def set_preco(self, novo_preco):
        if novo_preco >= 0: self.__preco = novo_preco

    def aplicar_desconto(self, percentual):
        self.__preco -= self.__preco * (percentual / 100)

    def exibir_dados(self):
        print(f"{self.nome} | {', '.join(self.ingredientes)} | R${self.__preco:.2f}", end="")
        if self.tipo_molho: print(f" | Molho: {self.tipo_molho}")
        else: print()

class LancheVegano(Lanche):
    def __init__(self, nome, ingredientes, preco, tipo_molho=None, tipo_proteina="Vegetal"):
        super().__init__(nome, ingredientes, preco, tipo_molho)
        self.tipo_proteina = tipo_proteina

    def exibir_dados(self):
        super().exibir_dados()
        print(f"Tipo de proteína: {self.tipo_proteina}")

        #teste

class BancoDeDados:
    def __init__(self):
        self.lanches_db = []

    def inserir_lanche(self, lanche):
        self.lanches_db.append(lanche)

    def listar_lanches(self):
        if self.lanches_db:
            for lanche in self.lanches_db: lanche.exibir_dados()
        else: print("Nenhum lanche encontrado.")

    def excluir_lanche(self, nome):
        self.lanches_db = [lanche for lanche in self.lanches_db if lanche.nome != nome]

def main():
    banco = BancoDeDados()
    lanche1 = Lanche("X-Burger", ["Pão", "Carne", "Queijo"], 12.50)
    lanche2 = LancheVegano("X-Vegano", ["Pão", "Alface", "Tomate"], 18.00, "Molho Pesto", "Tofu")
    
    banco.inserir_lanche(lanche1)
    banco.inserir_lanche(lanche2)
    
    banco.listar_lanches()

    lanche1.aplicar_desconto(10)
    lanche2.aplicar_desconto(5)
    
    banco.excluir_lanche("X-Burger")
    
    banco.listar_lanches()

if __name__ == "__main__":
    main()
# Out:
# X-Burger | Pão, Carne, Queijo | R$12.50
# X-Vegano | Pão, Alface, Tomate | R$18.00 | Molho: Molho Pesto
# Tipo de proteína: Tofu
# X-Vegano | Pão, Alface, Tomate | R$17.10 | Molho: Molho Pesto
# Tipo de proteína: Tofu
